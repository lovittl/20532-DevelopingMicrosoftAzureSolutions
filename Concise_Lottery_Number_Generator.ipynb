# %% [markdown]
# <a href="https://colab.research.google.com/github/lovittl/20532-DevelopingMicrosoftAzureSolutions/blob/b-release/Concise_Lottery_Number_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
def g(n,m): return sorted(random.sample(range(1,m+1),n)) if 0<n<=m else []

print(g(6, 53))
# Out:
# [14, 19, 20, 39, 42, 46]
